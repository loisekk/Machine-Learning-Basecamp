# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('customer_churn_prediction_dataset.csv')

# %%
#1. See your Data.
df.head()
# Out:
#   customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  0001-XXXX    Male              0     Yes        Yes       5           No
# 1  0002-XXXX  Female              0      No         No      42          Yes
# 2  0003-XXXX    Male              0      No         No      61          Yes
# 3  0004-XXXX    Male              1      No        Yes      22          Yes
# 4  0005-XXXX    Male              1     Yes        Yes      21           No
#
#       MultipleLines InternetService       OnlineSecurity  ...  \
# 0               Yes              No                   No  ...
# 1  No phone service             DSL                  Yes  ...
# 2  No phone service              No                   No  ...
# 3                No              No  No internet service  ...
# 4                No             DSL                   No  ...
#
#       DeviceProtection TechSupport          StreamingTV      StreamingMovies  \
# 0                   No          No                   No  No internet service
# 1                   No          No  No internet service  No internet service
# 2                   No         Yes                  Yes                   No
# 3                  Yes          No  No internet service                  Yes
# 4  No internet service          No                   No  No internet service
#
#          Contract PaperlessBilling     PaymentMethod MonthlyCharges  \
# 0  Month-to-month              Yes       Credit card          27.43
# 1        Two year               No  Electronic check          38.28
# 2        One year               No     Bank transfer         106.44
# 3  Month-to-month               No  Electronic check          92.49
# 4        One year               No     Bank transfer          19.63
#
#    TotalCharges  Churn
# 0        137.15    Yes
# 1       1607.76    Yes
# 2       6492.84    Yes
# 3       2034.78     No
# 4        412.23    Yes
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (300, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        300 non-null    object
#  1   gender            300 non-null    object
#  2   SeniorCitizen     300 non-null    int64
#  3   Partner           300 non-null    object
#  4   Dependents        300 non-null    object
#  5   tenure            300 non-null    int64
#  6   PhoneService      300 non-null    object
#  7   MultipleLines     300 non-null    object
#  8   InternetService   300 non-null    object
#  9   OnlineSecurity    300 non-null    object
#  10  OnlineBackup      300 non-null    object
#  11  DeviceProtection  300 non-null    object
#  12  TechSupport       300 non-null    object
#  13  StreamingTV       300 non-null    object
#  14  StreamingMovies   300 non-null    object
#  15  Contract          300 non-null    object
#  16  PaperlessBilling  300 non-null    object
#  17  PaymentMethod     300 non-null    object
#  18  MonthlyCharges    300 non-null    float64
#  19  TotalCharges      300 non-null    float64
#  20  Churn             300 non-null    object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 49.3+ KB

# %%
#EDA (Exploratory Data Analysis).
#1. Check null values
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#2. Check for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#3. Statistical terms
df.describe()
# Out:
#        SeniorCitizen      tenure  MonthlyCharges  TotalCharges
# count     300.000000  300.000000      300.000000    300.000000
# mean        0.543333   35.783333       67.226800   2477.975767
# std         0.498951   21.113400       28.638073   1918.540111
# min         0.000000    1.000000       18.450000     30.030000
# 25%         0.000000   17.000000       42.337500    910.302500
# 50%         1.000000   36.000000       68.635000   2072.400000
# 75%         1.000000   53.250000       92.430000   3618.405000
# max         1.000000   72.000000      118.640000   8318.880000

# %%
#4. Outliers

# %%
# Class Imbalance

# %%
sns.countplot(x=df['Churn'])
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
df.head()
# Out:
#   customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  0001-XXXX    Male              0     Yes        Yes       5           No
# 1  0002-XXXX  Female              0      No         No      42          Yes
# 2  0003-XXXX    Male              0      No         No      61          Yes
# 3  0004-XXXX    Male              1      No        Yes      22          Yes
# 4  0005-XXXX    Male              1     Yes        Yes      21           No
#
#       MultipleLines InternetService       OnlineSecurity  ...  \
# 0               Yes              No                   No  ...
# 1  No phone service             DSL                  Yes  ...
# 2  No phone service              No                   No  ...
# 3                No              No  No internet service  ...
# 4                No             DSL                   No  ...
#
#       DeviceProtection TechSupport          StreamingTV      StreamingMovies  \
# 0                   No          No                   No  No internet service
# 1                   No          No  No internet service  No internet service
# 2                   No         Yes                  Yes                   No
# 3                  Yes          No  No internet service                  Yes
# 4  No internet service          No                   No  No internet service
#
#          Contract PaperlessBilling     PaymentMethod MonthlyCharges  \
# 0  Month-to-month              Yes       Credit card          27.43
# 1        Two year               No  Electronic check          38.28
# 2        One year               No     Bank transfer         106.44
# 3  Month-to-month               No  Electronic check          92.49
# 4        One year               No     Bank transfer          19.63
#
#    TotalCharges  Churn
# 0        137.15    Yes
# 1       1607.76    Yes
# 2       6492.84    Yes
# 3       2034.78     No
# 4        412.23    Yes
#
# [5 rows x 21 columns]

# %%
#Let's plot a histogram for skewneess
sns.histplot(df['tenure'],kde=True)
# Out:
# <Axes: xlabel='tenure', ylabel='Count'>

# %%
df['tenure'].skew()
#0  -> data centralized
#>0 -> Right skewed
#<0 -> Left Skewed
# Out:
# np.float64(0.02166595203393328)

# %%
df.drop(columns=['customerID'],axis=1,inplace=True)

# %%
#One hot Encoding

#list honi chahiye jiske andar sirf 'object' data aaye
cat_cols = df.select_dtypes(include=['object']).columns.tolist()

# %%
cat_cols.remove('Churn')

# %%
cat_cols
# Out:
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod']

# %%
df_copy = pd.get_dummies(df,columns=cat_cols)

# %%
df_copy
# Out:
#      SeniorCitizen  tenure  MonthlyCharges  TotalCharges Churn  gender_Female  \
# 0                0       5           27.43        137.15   Yes          False
# 1                0      42           38.28       1607.76   Yes           True
# 2                0      61          106.44       6492.84   Yes          False
# 3                1      22           92.49       2034.78    No          False
# 4                1      21           19.63        412.23   Yes          False
# ..             ...     ...             ...           ...   ...            ...
# 295              1      61           42.52       2593.72    No           True
# 296              0      49           22.31       1093.19   Yes           True
# 297              0      71           59.57       4229.47   Yes          False
# 298              1       1           31.32         31.32    No          False
# 299              1      13           20.50        266.50   Yes           True
#
#      gender_Male  Partner_No  Partner_Yes  Dependents_No  ...  \
# 0           True       False         True          False  ...
# 1          False        True        False           True  ...
# 2           True        True        False           True  ...
# 3           True        True        False          False  ...
# 4           True       False         True          False  ...
# ..           ...         ...          ...            ...  ...
# 295        False        True        False          False  ...
# 296        False        True        False           True  ...
# 297         True        True        False          False  ...
# 298         True       False         True          False  ...
# 299        False       False         True          False  ...
#
#      StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# 0                  False                     True              False
# 1                  False                    False              False
# 2                  False                    False               True
# 3                   True                     True              False
# 4                  False                    False               True
# ..                   ...                      ...                ...
# 295                False                    False               True
# 296                 True                     True              False
# 297                 True                    False              False
# 298                 True                    False              False
# 299                 True                     True              False
#
#      Contract_Two year  PaperlessBilling_No  PaperlessBilling_Yes  \
# 0                False                False                  True
# 1                 True                 True                 False
# 2                False                 True                 False
# 3                False                 True                 False
# 4                False                 True                 False
# ..                 ...                  ...                   ...
# 295              False                False                  True
# 296              False                False                  True
# 297               True                 True                 False
# 298               True                 True                 False
# 299              False                 True                 False
#
#      PaymentMethod_Bank transfer  PaymentMethod_Credit card  \
# 0                          False                       True
# 1                          False                      False
# 2                           True                      False
# 3                          False                      False
# 4                           True                      False
# ..                           ...                        ...
# 295                        False                      False
# 296                        False                      False
# 297                        False                      False
# 298                        False                       True
# 299                        False                      False
#
#      PaymentMethod_Electronic check  PaymentMethod_Mailed check
# 0                             False                       False
# 1                              True                       False
# 2                             False                       False
# 3                              True                       False
# 4                             False                       False
# ..                              ...                         ...
# 295                            True                       False
# 296                           False                        True
# 297                           False                        True
# 298                           False                       False
# 299                            True                       False
#
# [300 rows x 46 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_copy['Churn'] =  le.fit_transform(df['Churn'])

# %%
df_copy
# Out:
#      SeniorCitizen  tenure  MonthlyCharges  TotalCharges  Churn  \
# 0                0       5           27.43        137.15      1
# 1                0      42           38.28       1607.76      1
# 2                0      61          106.44       6492.84      1
# 3                1      22           92.49       2034.78      0
# 4                1      21           19.63        412.23      1
# ..             ...     ...             ...           ...    ...
# 295              1      61           42.52       2593.72      0
# 296              0      49           22.31       1093.19      1
# 297              0      71           59.57       4229.47      1
# 298              1       1           31.32         31.32      0
# 299              1      13           20.50        266.50      1
#
#      gender_Female  gender_Male  Partner_No  Partner_Yes  Dependents_No  ...  \
# 0            False         True       False         True          False  ...
# 1             True        False        True        False           True  ...
# 2            False         True        True        False           True  ...
# 3            False         True        True        False          False  ...
# 4            False         True       False         True          False  ...
# ..             ...          ...         ...          ...            ...  ...
# 295           True        False        True        False          False  ...
# 296           True        False        True        False           True  ...
# 297          False         True        True        False          False  ...
# 298          False         True       False         True          False  ...
# 299           True        False       False         True          False  ...
#
#      StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# 0                  False                     True              False
# 1                  False                    False              False
# 2                  False                    False               True
# 3                   True                     True              False
# 4                  False                    False               True
# ..                   ...                      ...                ...
# 295                False                    False               True
# 296                 True                     True              False
# 297                 True                    False              False
# 298                 True                    False              False
# 299                 True                     True              False
#
#      Contract_Two year  PaperlessBilling_No  PaperlessBilling_Yes  \
# 0                False                False                  True
# 1                 True                 True                 False
# 2                False                 True                 False
# 3                False                 True                 False
# 4                False                 True                 False
# ..                 ...                  ...                   ...
# 295              False                False                  True
# 296              False                False                  True
# 297               True                 True                 False
# 298               True                 True                 False
# 299              False                 True                 False
#
#      PaymentMethod_Bank transfer  PaymentMethod_Credit card  \
# 0                          False                       True
# 1                          False                      False
# 2                           True                      False
# 3                          False                      False
# 4                           True                      False
# ..                           ...                        ...
# 295                        False                      False
# 296                        False                      False
# 297                        False                      False
# 298                        False                       True
# 299                        False                      False
#
#      PaymentMethod_Electronic check  PaymentMethod_Mailed check
# 0                             False                       False
# 1                              True                       False
# 2                             False                       False
# 3                              True                       False
# 4                             False                       False
# ..                              ...                         ...
# 295                            True                       False
# 296                           False                        True
# 297                           False                        True
# 298                           False                       False
# 299                            True                       False
#
# [300 rows x 46 columns]

# %%
#Split X and y variables for model training and testing
X = df_copy.drop(columns=['Churn'])
y = df_copy['Churn']
