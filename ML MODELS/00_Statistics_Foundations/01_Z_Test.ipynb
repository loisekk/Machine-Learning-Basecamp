# %%
import numpy as np
from scipy.stats import norm

# %%
sample = np.array([
    172, 174, 168, 169, 171, 173, 175, 170, 169, 172,
    171, 173, 174, 168, 170, 172, 171, 169, 173, 174,
    170, 171, 172, 173, 169, 168, 174, 175, 170, 171
])
Population_mean = 170
Population_std = 3

sample_mean = np.mean(sample)
n = len(sample)

print("Sample Mean:", sample_mean)
print("Z-score:", z_score)
# Out:
# Sample Mean: 171.36666666666667
# Z-score: 1.3703203194063098

# %%
z_score = (sample_mean - Population_mean) / ( Population_std /np.sqrt(n))
z_score
# Out:
# np.float64(1.3703203194063098)

# %%
p_value = 2 * ( 1 - norm.cdf(abs(z_score))) # cdf -> Cumulative Distribution Function

# %%
p_value
# Out:
# np.float64(0.17058693287143756)

# %%
alpha =  0.05

# %%
if p_value < alpha :
    print("I will reject my null hypothesis ")
