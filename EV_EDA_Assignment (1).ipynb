# %% [markdown]
# # ⚡ Electric Vehicle Population — EDA Assignment
#
# **Dataset:** `Electric_Vehicle_Population_Data.xls` (~191K rows, 17 columns)
#
# **Tip:** File has `.xls` extension but is a CSV — use `pd.read_csv()` directly.

# %% [markdown]
# ## Q1 — Environment Setup
# Import: `numpy`, `pandas`, `matplotlib.pyplot`, `seaborn`, `scipy.stats`, `warnings`.

# %%
# ✍️ Write your code here
import pandas as pd  
import matplotlib.pyplot as plt 
import seaborn as sn 
import numpy as np 
import plotly.express as px 
import plotly.graph_objects as go

# %% [markdown]
# ## Q2 — Load Dataset & Initial Inspection
# Load into `df`. Display first and last 5 rows.

# %%
# ✍️ Write your code here
df = pd.read_csv('Electric_Vehicle_Population_Data.xls')
df
# Out:
#         VIN (1-10)        County       City State  Postal Code  Model Year  \
# 0       5YJSA1E22K          King    Seattle    WA      98112.0        2019
# 1       3MW39FS05R        Yakima     Zillah    WA      98953.0        2024
# 2       1N4AZ0CP0F          King       Kent    WA      98031.0        2015
# 3       5YJSA1H20F     Snohomish    Bothell    WA      98012.0        2015
# 4       JTMAB3FV1N        Yakima     Yakima    WA      98908.0        2022
# ...            ...           ...        ...   ...          ...         ...
# 191402  5YJ3E1EA0K        Pierce     Sumner    WA      98390.0        2019
# 191403  JN1BF0BA7P        Pierce   Wilkeson    WA      98396.0        2023
# 191404  7SAYGDEE4R          King  Fall City    WA      98024.0        2024
# 191405  7SAXCBE65N  Grays Harbor   Aberdeen    WA      98520.0        2022
# 191406  7SAYGAEEXP        Benton   Richland    WA      99352.0        2023
#
# ...

# %%
# ✍️ Write your code here
df.head()
# Out:
#    VIN (1-10)     County     City State  Postal Code  Model Year    Make  \
# 0  5YJSA1E22K       King  Seattle    WA      98112.0        2019   TESLA
# 1  3MW39FS05R     Yakima   Zillah    WA      98953.0        2024     BMW
# 2  1N4AZ0CP0F       King     Kent    WA      98031.0        2015  NISSAN
# 3  5YJSA1H20F  Snohomish  Bothell    WA      98012.0        2015   TESLA
# 4  JTMAB3FV1N     Yakima   Yakima    WA      98908.0        2022  TOYOTA
#
#         Model                   Electric Vehicle Type  \
# 0     MODEL S          Battery Electric Vehicle (BEV)
# 1        330E  Plug-in Hybrid Electric Vehicle (PHEV)
# 2        LEAF          Battery Electric Vehicle (BEV)
# 3     MODEL S          Battery Electric Vehicle (BEV)
# 4  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             270
# ...

# %% [markdown]
# ## Q3 — Shape, Data Types & Summary Statistics
# Print `.shape`, `.dtypes`, `.info()`, and `.describe(include='all')`.

# %%
# ✍️ Write your code here
df.shape
# Out:
# (191407, 17)

# %%
# ✍️ Write your code here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191407 entries, 0 to 191406
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         191407 non-null  object
#  1   County                                             191403 non-null  object
#  2   City                                               191403 non-null  object
#  3   State                                              191407 non-null  object
#  4   Postal Code                                        191403 non-null  float64
#  5   Model Year                                         191407 non-null  int64
#  6   Make                                               191407 non-null  object
#  7   Model                                              191407 non-null  object
# ...

# %%
# ✍️ Write your code here
df.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  191403.000000  191407.000000   191407.000000  191407.000000
# mean    98177.823603    2020.732335       55.657442     994.773258
# std      2392.808886       2.990487       90.151930    8050.523372
# min      1731.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2019.000000        0.000000       0.000000
# 50%     98125.000000    2022.000000        0.000000       0.000000
# 75%     98371.000000    2023.000000       72.000000       0.000000
# max     99577.000000    2025.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         190993.000000    1.914070e+05       1.914030e+05
# mean              29.016880    2.237202e+08       5.297759e+10
# std               14.909417    7.398058e+07       1.573588e+09
# min                1.000000    4.385000e+03       1.001020e+09
# ...

# %% [markdown]
# ## Q4 — Identify Numeric & Categorical Columns
# Use `select_dtypes()` to list both types separately.

# %%
# ✍️ Write your code here
df.select_dtypes(object)
df.select_dtypes(int)
# Out:
#         Model Year  Electric Range  Base MSRP  DOL Vehicle ID
# 0             2019             270          0       202233958
# 1             2024              20          0       264425178
# 2             2015              84          0       114962025
# 3             2015             208          0       232724670
# 4             2022              42          0       221023589
# ...            ...             ...        ...             ...
# 191402        2019             220          0       314927896
# 191403        2023               0          0       236213120
# 191404        2024               0          0       261335896
# 191405        2022               0          0       219273491
# 191406        2023               0          0       233761440
#
# [191407 rows x 4 columns]

# %% [markdown]
# ## Q5 — Missing Value Analysis
# Create a `missing` DataFrame with **count** and **percentage** of nulls per column.
# Show only columns where count > 0. Plot a bar chart of missing percentages.

# %%
# ✍️ Write your code here
df.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 4
# City                                                   4
# State                                                  0
# Postal Code                                            4
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 414
# DOL Vehicle ID                                         0
# Vehicle Location                                       8
# Electric Utility                                       4
# ...

# %% [markdown]
# ## Q6 — Clean Copy & Handle Missing Values
# Create `df_clean = df.copy()`. Fill:
# - `County`, `City` → `'Unknown'`
# - `Postal Code`, `Legislative District` → `0`
#
# Verify with `.isnull().sum().sum()`.

# %%
# ✍️ Write your code here
df_clean = df.copy()
df_clean.isnull().sum().sum()
# Out:
# np.int64(442)

# %% [markdown]
# ## Q7 — Remove Duplicate Records
# Print duplicate count. Drop them. Print shape before and after.

# %%
# ✍️ Write your code here

df_clean = df_clean.duplicated()
df_clean.sum()
# Out:
# np.int64(191405)

# %%
df_range = df_clean
df_range
# Out:
# 0         False
# 1         False
# 2          True
# 3          True
# 4          True
#           ...
# 191402     True
# 191403     True
# 191404     True
# 191405     True
# 191406     True
# Length: 191407, dtype: bool

# %% [markdown]
# ## Q8 — Filter Invalid Electric Range Values
# Count rows where `Electric Range == 0`. Create `df_range` excluding them.
# Plot a histogram and print mean, median, std of the filtered range.

# %%
# df_clean.drop_duplicates().sum()

mean = df['Electric Range'].mean()
median = df['Electric Range'].median()
std = df['Electric Range'].std()
print(mean)
print(median)
print(std)
# Out:
# 55.65744199532932
# 0.0
# 90.15192984184792

# %%
df_range = df['Electric Range']

# %%
sn.histplot( df, x = mean)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 sn.histplot( df, x = mean)
#
# File ~\anaconda3\Lib\site-packages\seaborn\distributions.py:1379, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1358 def histplot(
#    1359     data=None, *,
#    1360     # Vector variables
#    (...)   1376     **kwargs,
#    1377 ):
# -> 1379     p = _DistributionPlotter(
#    1380         data=data,
#    1381         variables=dict(x=x, y=y, hue=hue, weights=weights),
#    1382     )
#    1384     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#    1386     if ax is None:
#
# ...

# %% [markdown]
# ## Q9 — Top 10 EV Manufacturers
# Use `.value_counts().head(10)` on `Make`. Plot a horizontal bar chart.

# %%
# ✍️ Write your code here
make= df['Make'].value_counts().head(10)
sn.boxplot(make)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Q10 — Year-wise EV Registration Trend
# Count registrations per `Model Year`. Plot a line chart with markers.

# %%
# ✍️ Write your code here
sn.lineplot(df , x = df['Model Year'] , y = df['Make'])
# Out:
# <Axes: xlabel='Model Year', ylabel='Make'>

# %% [markdown]
# ## Q11 — BEV vs PHEV Comparison
# Plot a 2-subplot figure: pie chart (%) + bar chart (counts) for `Electric Vehicle Type`.

# %%
# ✍️ Write your code here


ev_counts = df['Electric Vehicle Type'].value_counts()
fig, axes = plt.subplots(1, 2, figsize=(14, 6))


axes[0].pie(
    ev_counts.values,
    labels=ev_counts.index,
)


sn.barplot(
    x=ev_counts.index,
    y=ev_counts.values,
    ax=axes[1]
)
# Out:
# <Axes: xlabel='Electric Vehicle Type'>

# %% [markdown]
# ## Q12 — Top 10 Counties by EV Registrations
# Use `.value_counts().head(10)` on `County`. Plot a bar chart.

# %%
# ✍️ Write your code here

country  = df['County'].value_counts().head(10)
sn.barplot(df, y =  country)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Q13 — CAFV Eligibility Analysis
# Value counts for `Clean Alternative Fuel Vehicle (CAFV) Eligibility`. Plot a horizontal bar chart and print percentages.

# %%
# ✍️ Write your code here
sn.barplot(df , y = df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] ,  hue = 'Model')
# Out:
# <Axes: ylabel='Clean Alternative Fuel Vehicle (CAFV) Eligibility'>

# %% [markdown]
# ## Q14 — Electric Range by EV Type (Bivariate — Box Plot)
# Use `df_range`. Plot `sns.boxplot()` with EV Type on x-axis. Print median range per type.

# %%
# ✍️ Write your code here

median = df.groupby('Electric Vehicle Type')['Electric Range'].median()
print(median)
sn.boxplot(data=df, x='Electric Vehicle Type', y='Electric Range')
plt.show()
# Out:
# Electric Vehicle Type
# Battery Electric Vehicle (BEV)             0.0
# Plug-in Hybrid Electric Vehicle (PHEV)    30.0
# Name: Electric Range, dtype: float64

# %% [markdown]
# ## Q15 — IQR, Q1, Q2, Q3 for Electric Range
# Use `df_range`. Calculate Q1, Q2 (median), Q3, and IQR = Q3 − Q1.
# Print all values. *(Fences = Q1 ± 1.5×IQR)*

# %%
Q1 = df['Electric Range'].quantile(0.25)
Q2 = df['Electric Range'].quantile(0.50)   
Q3 = df['Electric Range'].quantile(0.75)

# %%
# ✍️ Write your code here
Q1 = df['Electric Range'].quantile(0.25)
Q2 = df['Electric Range'].quantile(0.50)   
Q3 = df['Electric Range'].quantile(0.75)
IQR = Q3 - Q1 
upper_fence = Q3 + (1.5 * IQR)
lower_fence = Q1 -  (1.5 * IQR)
print(upper_fence)
print(lower_fence)
# Out:
# 180.0
# -108.0

# %% [markdown]
# ## Q16 — IQR-Based Outlier Detection for Model Year
# Calculate Q1, Q3, IQR for `Model Year`. Define fences. Filter and display outlier records.

# %%
# ✍️ Write your code here

IQR = Q3 - Q1 
upper_fence = Q3 + (1.5 * IQR)
lower_fence = Q1 -  (1.5 * IQR)
print(upper_fence)
print(lower_fence)
# Out:
# 180.0
# -108.0

# %% [markdown]
# ## Q17 — Skewness Analysis
# Compute skewness for `Electric Range` (> 0) and `Base MSRP` (> 0) using `.skew()`.
# Interpret: `> 0` = right-skewed, `< 0` = left-skewed. Plot KDE curves for both.

# %%
# ✍️ Write your code here

# %% [markdown]
# ## Q18 — Z-Score Outlier Detection for Electric Range
# Use `scipy.stats.zscore()` on `df_range`. Flag outliers where `|Z| > 3`.
# Print count and percentage. Plot a histogram of Z-scores with threshold lines.

# %%
# ✍️ Write your code here
from scipy import scipy.stats.zscore
z_score =
# Out:
#   Cell In[155], line 2
#     from scipy import scipy.stats.zscore
#                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Q19 — Hypothesis Testing (T-Test: BEV vs PHEV Range)
# **H₀:** Mean Electric Range of BEV = PHEV | **H₁:** They are different
#
# Separate BEV and PHEV ranges (exclude 0s). Run `scipy.stats.ttest_ind()`.
# Print T-statistic, P-value. Conclude: if **p < 0.05** → reject H₀.

# %%
# ✍️ Write your code here

# %% [markdown]
# ## Q20 — Summary: Key Insights
# Print the following as a plain-language report:
# 1. Total registrations & dominant state
# 2. Top manufacturer & most common model year
# 3. BEV vs PHEV split (%)
# 4. Median Electric Range & IQR
# 5. Skewness interpretation
# 6. Z-Score outlier %
# 7. T-Test conclusion
# 8. Top county

# %%
# ✍️ Write your code here

print()
